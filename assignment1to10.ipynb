# %%
#1.
name = ''' Hi How are you?
Starterd learning python.
It's really interesting.'''

# %%
name[:]
# Out:
# " Hi How are you?\nStarterd learning python.\nIt's really interesting."

# %%
name[-10:-5]
# Out:
# 'teres'

# %%
name[3:12]
# Out:
# ' How are '

# %%
name[12:3]
# Out:
# ''

# %%
name[12:3]
# Out:
# ''

# %%
name[-4:-12]
# Out:
# ''

# %%
name[::2]
# Out:
# ' iHwaeyu\ntredlann yhn\ntsral neetn.'

# %%
name[::-2]
# Out:
# '.nteen larst\nnhy nnaldert\nuyeawHi '

# %%
#2.
L1 = ['a' , 'b', 20, 30, 't', 100, 300, 400, 'Happy', 'major']

# %%
L1[:]
# Out:
# ['a', 'b', 20, 30, 't', 100, 300, 400, 'Happy', 'major']

# %%
L1[::3]
# Out:
# ['a', 30, 300, 'major']

# %%
L1[::-2]
# Out:
# ['major', 400, 100, 30, 'b']

# %%
#How to extract  value “Happy” based on index and negative index
L1[8]
# Out:
# 'Happy'

# %%
#.	How to check type of data in list at 4th position
L1[3]
# Out:
# 30

# %%
#.	Extract values for 100, 300, 400
L1[5]
# Out:
# 100

# %%
L1[6]
# Out:
# 300

# %%
L1[7]
# Out:
# 400

# %%
#3.
I2 =[1,2,3,5,['a', 'b', 'work hard'],100 , 200, 'Success']

# %%
I2[4]
# Out:
# ['a', 'b', 'work hard']

# %%
I2[1:5]
# Out:
# [2, 3, 5, ['a', 'b', 'work hard']]

# %%
I2[7]
# Out:
# 'Success'

# %%
I2[7][2]
# Out:
# 'c'

# %%
I2[7][2:]
# Out:
# 'ccess'

# %%
I2[:3]
# Out:
# [1, 2, 3]

# %%
I2[3:]
# Out:
# [5, ['a', 'b', 'work hard'], 100, 200, 'Success']

# %%
#4.	From the above I2 value ‘b’ must be changed to ‘BEE’.
I2[4][1] = "BEE"
I2
# Out:
# [1, 2, 3, 5, ['a', 'BEE', 'work hard'], 100, 200, 'Success']

# %%
#5.	From l2 “BEE” has to discard.
I2[4].remove("BEE")
I2
# Out:
# [1, 2, 3, 5, ['a', 'work hard'], 100, 200, 'Success']

# %%
#6.	In l2 add a dictionary at the end {‘insect’: [‘bee’, ‘moth’] , ‘bird’ : [‘parrot’, ‘sparrow’]}
I2[4].append({'insect': ['bee', 'moth'],
              'bird': ['parrot', 'sparrow']})
I2
# Out:
# [1,
#  2,
#  3,
#  5,
#  ['a',
#   'work hard',
#   {'insect': ['bee', 'moth'], 'bird': ['parrot', 'sparrow']}],
#  100,
#  200,
#  'Success']

# %%
#7.	From l2 extract insect information.
I2[4][2]['insect']
# Out:
# ['bee', 'moth']

# %%
#8.	Create a dictionary d1 = {‘a’:10, ‘b’:20, ‘c’ : 30} and add the d1 at 2nd position of l2
d1 = {'a': 10, 'b': 20, 'c': 30}

I2[4].insert(1, d1)
I2
# Out:
# [1,
#  2,
#  3,
#  5,
#  ['a',
#   {'a': 10, 'b': 20, 'c': 30},
#   'work hard',
#   {'insect': ['bee', 'moth'], 'bird': ['parrot', 'sparrow']}],
#  100,
#  200,
#  'Success']

# %%
#9.	Based on new l2 created here extract the value 10 from l2 dictionary.

I2[4][1]['a']
# Out:
# 10

# %%
#10.
l2 =[1,2,3,5, (90,40,50,10), 'Python', 400 ,['a', 'b', 'work hard'],100 , 200, 'Success', (200,300, 'Hundreds')]

# %%
l2[4][2]
# Out:
# 50

# %%
l2[5][:]
# Out:
# 'Python'

# %%
l2[2][:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1444527719.py in <cell line: 0>()
# ----> 1 l2[2][:]
#
# TypeError: 'int' object is not subscriptable

# %%
l2[1:5]
# Out:
# [2, 3, 5, (90, 40, 50, 10)]

# %%
l2[5]
# Out:
# 'Python'

# %%
l2[5][3:-1]
# Out:
# 'ho'

# %%
l2[-1]
# Out:
# (200, 300, 'Hundreds')

# %%
l2[-4][-3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1307658282.py in <cell line: 0>()
# ----> 1 l2[-4][-3]
#
# TypeError: 'int' object is not subscriptable

# %%
l2[-4,-10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3905783409.py in <cell line: 0>()
# ----> 1 l2[-4,-10]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
l2[7][2]
# Out:
# 'work hard'

# %%
l2[-7][2:]
# Out:
# 'thon'

# %%
l2[ :- 3]
# Out:
# [1, 2, 3, 5, (90, 40, 50, 10), 'Python', 400, ['a', 'b', 'work hard'], 100]

# %%
l2[-3:]
# Out:
# [200, 'Success', (200, 300, 'Hundreds')]
